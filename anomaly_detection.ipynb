# %%
import anomaly_detection_functions as adf

# %%
contratos_df = adf.read_partitioned_csv("etl_data/contratos_infraesructura_df.csv")
contratos_df.head()
# Out:
#   REFERENCIA_CONTRATO              MUNICIPIO DEPARTAMENTO ESTADO_DEL_PROCESO  \
# 0            13312021                 BOGOTA       BOGOTA       EN EJECUCION
# 1    CO1PCCNTR2525614  SAN JOSE DEL GUAVIARE     GUAVIARE       EN EJECUCION
# 2          GGC6762021                 BOGOTA       BOGOTA             ACTIVO
# 3    CO1PCCNTR2090854               MEDELLIN    ANTIOQUIA       EN EJECUCION
# 4        2020AS390080               MEDELLIN    ANTIOQUIA       EN EJECUCION
#
#            FECHA_INICIO_CONTRATO             FECHA_FIN_CONTRATO  \
# 0  2021-06-01T00:00:00.000-05:00  2021-11-30T00:00:00.000-05:00
# 1  2021-05-24T00:00:00.000-05:00  2021-06-04T00:00:00.000-05:00
# 2  1900-01-01T00:00:00.000-04:56  2041-10-11T00:00:00.000-05:00
# 3  2021-05-20T00:00:00.000-05:00  2021-06-30T00:00:00.000-05:00
# 4  2021-03-30T00:00:00.000-05:00  2021-06-30T00:00:00.000-05:00
#
#                  CLASE_PROCESO                TIPO_PROCESO  \
# 0         CONTRATACION DIRECTA  ARRENDAMIENTO DE INMUEBLES
# 1  CONTRATACION MINIMA CUANTIA     PRESTACION DE SERVICIOS
# 2                          NaN                        OTRO
# 3         CONTRATACION DIRECTA                        OTRO
# 4         CONTRATACION DIRECTA                        OTRO
#
#                       TIPO_CONTRATO  \
# 0              CONTRATACION DIRECTA
# 1                    MINIMA CUANTIA
# 2  CONTRATACION DIRECTA CON OFERTAS
# 3              CONTRATACION DIRECTA
# 4              CONTRATACION DIRECTA
#
#                                       NOMBRE_ENTIDAD  NIT_ENTIDAD  \
# 0  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473
# 1  CONTRALORIA GENERAL DE LA REPUBLICA GERENCIA D...    899999067
# 2           MINISTERIO DE MINAS Y ENERGIA - MINMINAS    899999022
# 3                            ANTIOQUIA - GOBERNACION    890900286
# 4                            ANTIOQUIA - GOBERNACION    890900286
#
#    ID_CONTRATISTA                  RAZON_SOCIAL_CONTRATISTA  \
# 0      40445244.0            MONICA ALEJANDRA  TORRES PORES
# 1     830033765.0    INVERSER LTDA  INVERSIONES Y SERVICIOS
# 2     892099499.0  EMPRESA DE ENERGIA DE ARAUCA  ENELAR ESP
# 3     890983813.0       MUNICIPIO DE EL SANTUARIO ANTIOQUIA
# 4     890983736.0                  MUNICIPIO DE SABANALARGA
#
#    VALOR_TOTAL_CONTRATO          NOMBRE_GRUPO  \
# 0              27000000             EJECUTIVO
# 1               1424239  CORPORACION AUTONOMA
# 2            8363818392             EJECUTIVO
# 3             433180320             EJECUTIVO
# 4             249161352             EJECUTIVO
#
#                       NOMBRE_FAMILIA                       NOMBRE_CLASE  \
# 0  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION
# 1              NO APLICANO PERTENECE              NO APLICANO PERTENECE
# 2                    MINAS Y ENERGIA                    MINAS Y ENERGIA
# 3                   SERVICIO PUBLICO                   SERVICIO PUBLICO
# 4                   SERVICIO PUBLICO                   SERVICIO PUBLICO
#
#    month  year
# 0      6  2021
# 1      5  2021
# 2      9  2021
# 3      5  2021
# 4      3  2021

# %%
directorio = "clustering_data"
nombre_archivo = "entidades_clustered_df.csv"
delimitador = "," 

entidades_clustered_df = adf.leer_csv(directorio, nombre_archivo, delimitador)
entidades_clustered_df = entidades_clustered_df[["NIT_ENTIDAD","cluster"]]

entidades_clustered_df = entidades_clustered_df.drop_duplicates(subset=["NIT_ENTIDAD"])


entidades_clustered_df.head()
# Out:
#    NIT_ENTIDAD  cluster
# 0    805027641        0
# 1    899999034        2
# 2   8605110716        2
# 3    830063506        6
# 4    900816913        4

# %%
directorio = "clustering_data"
nombre_archivo = "indice_transparencia.csv"
delimitador = "," 

indice_transparencia_df = adf.leer_csv(directorio, nombre_archivo, delimitador)
indice_transparencia_df = indice_transparencia_df[["cluster","indice_de_transparencia"]]
indice_transparencia_df.head()
# Out:
#    cluster  indice_de_transparencia
# 0        0                 0.019681
# 1        1                 0.076455
# 2        2                 0.052300
# 3        3                 0.002323
# 4        4                 0.005554

# %%
entidades_indice = entidades_clustered_df.merge(indice_transparencia_df, on="cluster", how="left")
entidades_indice.head()
# Out:
#    NIT_ENTIDAD  cluster  indice_de_transparencia
# 0    805027641        0                 0.019681
# 1    899999034        2                 0.052300
# 2   8605110716        2                 0.052300
# 3    830063506        6                 0.078983
# 4    900816913        4                 0.005554

# %%
contratos_indice = contratos_df.merge(entidades_indice, on="NIT_ENTIDAD", how="left")
contratos_indice.head()
# Out:
#   REFERENCIA_CONTRATO              MUNICIPIO DEPARTAMENTO ESTADO_DEL_PROCESO  \
# 0            13312021                 BOGOTA       BOGOTA       EN EJECUCION
# 1    CO1PCCNTR2525614  SAN JOSE DEL GUAVIARE     GUAVIARE       EN EJECUCION
# 2          GGC6762021                 BOGOTA       BOGOTA             ACTIVO
# 3    CO1PCCNTR2090854               MEDELLIN    ANTIOQUIA       EN EJECUCION
# 4        2020AS390080               MEDELLIN    ANTIOQUIA       EN EJECUCION
#
#            FECHA_INICIO_CONTRATO             FECHA_FIN_CONTRATO  \
# 0  2021-06-01T00:00:00.000-05:00  2021-11-30T00:00:00.000-05:00
# 1  2021-05-24T00:00:00.000-05:00  2021-06-04T00:00:00.000-05:00
# 2  1900-01-01T00:00:00.000-04:56  2041-10-11T00:00:00.000-05:00
# 3  2021-05-20T00:00:00.000-05:00  2021-06-30T00:00:00.000-05:00
# 4  2021-03-30T00:00:00.000-05:00  2021-06-30T00:00:00.000-05:00
#
#                  CLASE_PROCESO                TIPO_PROCESO  \
# 0         CONTRATACION DIRECTA  ARRENDAMIENTO DE INMUEBLES
# 1  CONTRATACION MINIMA CUANTIA     PRESTACION DE SERVICIOS
# 2                          NaN                        OTRO
# 3         CONTRATACION DIRECTA                        OTRO
# 4         CONTRATACION DIRECTA                        OTRO
#
#                       TIPO_CONTRATO  \
# 0              CONTRATACION DIRECTA
# 1                    MINIMA CUANTIA
# 2  CONTRATACION DIRECTA CON OFERTAS
# 3              CONTRATACION DIRECTA
# 4              CONTRATACION DIRECTA
#
#                                       NOMBRE_ENTIDAD  ...  ID_CONTRATISTA  \
# 0  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...  ...      40445244.0
# 1  CONTRALORIA GENERAL DE LA REPUBLICA GERENCIA D...  ...     830033765.0
# 2           MINISTERIO DE MINAS Y ENERGIA - MINMINAS  ...     892099499.0
# 3                            ANTIOQUIA - GOBERNACION  ...     890983813.0
# 4                            ANTIOQUIA - GOBERNACION  ...     890983736.0
#
#                    RAZON_SOCIAL_CONTRATISTA VALOR_TOTAL_CONTRATO  \
# 0            MONICA ALEJANDRA  TORRES PORES             27000000
# 1    INVERSER LTDA  INVERSIONES Y SERVICIOS              1424239
# 2  EMPRESA DE ENERGIA DE ARAUCA  ENELAR ESP           8363818392
# 3       MUNICIPIO DE EL SANTUARIO ANTIOQUIA            433180320
# 4                  MUNICIPIO DE SABANALARGA            249161352
#
#            NOMBRE_GRUPO                     NOMBRE_FAMILIA  \
# 0             EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
# 1  CORPORACION AUTONOMA              NO APLICANO PERTENECE
# 2             EJECUTIVO                    MINAS Y ENERGIA
# 3             EJECUTIVO                   SERVICIO PUBLICO
# 4             EJECUTIVO                   SERVICIO PUBLICO
#
#                         NOMBRE_CLASE month  year  cluster  \
# 0  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
# 1              NO APLICANO PERTENECE     5  2021      2.0
# 2                    MINAS Y ENERGIA     9  2021      5.0
# 3                   SERVICIO PUBLICO     5  2021      2.0
# 4                   SERVICIO PUBLICO     3  2021      2.0
#
#    indice_de_transparencia
# 0                 0.499161
# 1                 0.052300
# 2                 0.499161
# 3                 0.052300
# 4                 0.052300
#
# [5 rows x 21 columns]

# %%
contratos_indice.columns

contratos_indice.index = contratos_indice['REFERENCIA_CONTRATO']
contratos_indice = contratos_indice.drop(columns=['REFERENCIA_CONTRATO'])
contratos_indice.head()


numerical_columns = ["VALOR_TOTAL_CONTRATO"]
categorical_columns = ["TIPO_CONTRATO", "NOMBRE_GRUPO", "NOMBRE_FAMILIA", "NOMBRE_CLASE"]

preprocessed_contratos = adf.preprocess_data(contratos_indice, numerical_columns, categorical_columns)
preprocessed_contratos["cluster"] = contratos_indice["cluster"]

preprocessed_contratos.head()
# Out:
#                      VALOR_TOTAL_CONTRATO  \
# REFERENCIA_CONTRATO
# 13312021                        -0.019532
# CO1PCCNTR2525614                -0.023962
# GGC6762021                       1.424396
# CO1PCCNTR2090854                 0.050818
# 2020AS390080                     0.018946
#
#                      TIPO_CONTRATO_CONCURSO DE MERITOS ABIERTO  \
# REFERENCIA_CONTRATO
# 13312021                                                     0
# CO1PCCNTR2525614                                             0
# GGC6762021                                                   0
# CO1PCCNTR2090854                                             0
# 2020AS390080                                                 0
#
#                      TIPO_CONTRATO_CONTRATACION DIRECTA  \
# REFERENCIA_CONTRATO
# 13312021                                              1
# CO1PCCNTR2525614                                      0
# GGC6762021                                            0
# CO1PCCNTR2090854                                      1
# 2020AS390080                                          1
#
#                      TIPO_CONTRATO_CONTRATACION DIRECTA CON OFERTAS  \
# REFERENCIA_CONTRATO
# 13312021                                                          0
# CO1PCCNTR2525614                                                  0
# GGC6762021                                                        1
# CO1PCCNTR2090854                                                  0
# 2020AS390080                                                      0
#
#                      TIPO_CONTRATO_CONTRATACION REGIMEN ESPECIAL  \
# REFERENCIA_CONTRATO
# 13312021                                                       0
# CO1PCCNTR2525614                                               0
# GGC6762021                                                     0
# CO1PCCNTR2090854                                               0
# 2020AS390080                                                   0
#
#                      TIPO_CONTRATO_CONTRATACION REGIMEN ESPECIAL CON OFERTAS  \
# REFERENCIA_CONTRATO
# 13312021                                                             0
# CO1PCCNTR2525614                                                     0
# GGC6762021                                                           0
# CO1PCCNTR2090854                                                     0
# 2020AS390080                                                         0
#
#                      TIPO_CONTRATO_ENAJENACION DE BIENES CON SOBRE CERRADO  \
# REFERENCIA_CONTRATO
# 13312021                                                             0
# CO1PCCNTR2525614                                                     0
# GGC6762021                                                           0
# CO1PCCNTR2090854                                                     0
# 2020AS390080                                                         0
#
#                      TIPO_CONTRATO_ENAJENACION DE BIENES CON SUBASTA  \
# REFERENCIA_CONTRATO
# 13312021                                                           0
# CO1PCCNTR2525614                                                   0
# GGC6762021                                                         0
# CO1PCCNTR2090854                                                   0
# 2020AS390080                                                       0
#
#                      TIPO_CONTRATO_LICITACION PUBLICA  \
# REFERENCIA_CONTRATO
# 13312021                                            0
# CO1PCCNTR2525614                                    0
# GGC6762021                                          0
# CO1PCCNTR2090854                                    0
# 2020AS390080                                        0
#
#                      TIPO_CONTRATO_LICITACION PUBLICA ACUERDO MARCO DE PRECIOS  \
# REFERENCIA_CONTRATO
# 13312021                                                             0
# CO1PCCNTR2525614                                                     0
# GGC6762021                                                           0
# CO1PCCNTR2090854                                                     0
# 2020AS390080                                                         0
#
#                      ...  NOMBRE_CLASE_PLANEACION  \
# REFERENCIA_CONTRATO  ...
# 13312021             ...                        0
# CO1PCCNTR2525614     ...                        0
# GGC6762021           ...                        0
# CO1PCCNTR2090854     ...                        0
# 2020AS390080         ...                        0
#
#                      NOMBRE_CLASE_PRESIDENCIA DE LA REPUBLICA  \
# REFERENCIA_CONTRATO
# 13312021                                                    0
# CO1PCCNTR2525614                                            0
# GGC6762021                                                  0
# CO1PCCNTR2090854                                            0
# 2020AS390080                                                0
#
#                      NOMBRE_CLASE_RELACIONES EXTERIORES  \
# REFERENCIA_CONTRATO
# 13312021                                              0
# CO1PCCNTR2525614                                      0
# GGC6762021                                            0
# CO1PCCNTR2090854                                      0
# 2020AS390080                                          0
#
#                      NOMBRE_CLASE_SALUD Y PROTECCION SOCIAL  \
# REFERENCIA_CONTRATO
# 13312021                                                  0
# CO1PCCNTR2525614                                          0
# GGC6762021                                                0
# CO1PCCNTR2090854                                          0
# 2020AS390080                                              0
#
#                      NOMBRE_CLASE_SERVICIO PUBLICO  \
# REFERENCIA_CONTRATO
# 13312021                                         0
# CO1PCCNTR2525614                                 0
# GGC6762021                                       0
# CO1PCCNTR2090854                                 1
# 2020AS390080                                     1
#
#                      NOMBRE_CLASE_TECNOLOGIAS DE LA INFORMACION Y LAS COMUNICACIONES  \
# REFERENCIA_CONTRATO
# 13312021                                                             0
# CO1PCCNTR2525614                                                     0
# GGC6762021                                                           0
# CO1PCCNTR2090854                                                     0
# 2020AS390080                                                         0
#
#                      NOMBRE_CLASE_TRABAJO  NOMBRE_CLASE_TRANSPORTE  \
# REFERENCIA_CONTRATO
# 13312021                                0                        0
# CO1PCCNTR2525614                        0                        0
# GGC6762021                              0                        0
# CO1PCCNTR2090854                        0                        0
# 2020AS390080                            0                        0
#
#                      NOMBRE_CLASE_VIVIENDA CIUDAD Y TERRITORIO  cluster
# REFERENCIA_CONTRATO
# 13312021                                                     0      5.0
# CO1PCCNTR2525614                                             0      2.0
# GGC6762021                                                   0      5.0
# CO1PCCNTR2090854                                             0      2.0
# 2020AS390080                                                 0      2.0
#
# [5 rows x 70 columns]

# %%
features = preprocessed_contratos.columns

anomalous_data = adf.detect_anomalies(preprocessed_contratos, 'cluster', features)

anomalous_data["original_index"] = anomalous_data.index
anomalous_data = anomalous_data[["anomaly_score"]]

anomalous_data.head()
# Out:
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# /home/elchristog/.local/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
#                   anomaly_score
# original_index
# 13312021               0.827582
# CO1PCCNTR2525614       0.252774
# GGC6762021             0.376771
# CO1PCCNTR2090854       0.875663
# 2020AS390080           0.894961

# %%
contratos_indice.head()
# Out:
#                                  MUNICIPIO DEPARTAMENTO ESTADO_DEL_PROCESO  \
# REFERENCIA_CONTRATO
# 13312021                            BOGOTA       BOGOTA       EN EJECUCION
# CO1PCCNTR2525614     SAN JOSE DEL GUAVIARE     GUAVIARE       EN EJECUCION
# GGC6762021                          BOGOTA       BOGOTA             ACTIVO
# CO1PCCNTR2090854                  MEDELLIN    ANTIOQUIA       EN EJECUCION
# 2020AS390080                      MEDELLIN    ANTIOQUIA       EN EJECUCION
#
#                              FECHA_INICIO_CONTRATO  \
# REFERENCIA_CONTRATO
# 13312021             2021-06-01T00:00:00.000-05:00
# CO1PCCNTR2525614     2021-05-24T00:00:00.000-05:00
# GGC6762021           1900-01-01T00:00:00.000-04:56
# CO1PCCNTR2090854     2021-05-20T00:00:00.000-05:00
# 2020AS390080         2021-03-30T00:00:00.000-05:00
#
#                                 FECHA_FIN_CONTRATO  \
# REFERENCIA_CONTRATO
# 13312021             2021-11-30T00:00:00.000-05:00
# CO1PCCNTR2525614     2021-06-04T00:00:00.000-05:00
# GGC6762021           2041-10-11T00:00:00.000-05:00
# CO1PCCNTR2090854     2021-06-30T00:00:00.000-05:00
# 2020AS390080         2021-06-30T00:00:00.000-05:00
#
#                                    CLASE_PROCESO                TIPO_PROCESO  \
# REFERENCIA_CONTRATO
# 13312021                    CONTRATACION DIRECTA  ARRENDAMIENTO DE INMUEBLES
# CO1PCCNTR2525614     CONTRATACION MINIMA CUANTIA     PRESTACION DE SERVICIOS
# GGC6762021                                   NaN                        OTRO
# CO1PCCNTR2090854            CONTRATACION DIRECTA                        OTRO
# 2020AS390080                CONTRATACION DIRECTA                        OTRO
#
#                                         TIPO_CONTRATO  \
# REFERENCIA_CONTRATO
# 13312021                         CONTRATACION DIRECTA
# CO1PCCNTR2525614                       MINIMA CUANTIA
# GGC6762021           CONTRATACION DIRECTA CON OFERTAS
# CO1PCCNTR2090854                 CONTRATACION DIRECTA
# 2020AS390080                     CONTRATACION DIRECTA
#
#                                                         NOMBRE_ENTIDAD  \
# REFERENCIA_CONTRATO
# 13312021             UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...
# CO1PCCNTR2525614     CONTRALORIA GENERAL DE LA REPUBLICA GERENCIA D...
# GGC6762021                    MINISTERIO DE MINAS Y ENERGIA - MINMINAS
# CO1PCCNTR2090854                               ANTIOQUIA - GOBERNACION
# 2020AS390080                                   ANTIOQUIA - GOBERNACION
#
#                      NIT_ENTIDAD  ID_CONTRATISTA  \
# REFERENCIA_CONTRATO
# 13312021               900490473      40445244.0
# CO1PCCNTR2525614       899999067     830033765.0
# GGC6762021             899999022     892099499.0
# CO1PCCNTR2090854       890900286     890983813.0
# 2020AS390080           890900286     890983736.0
#
#                                      RAZON_SOCIAL_CONTRATISTA  \
# REFERENCIA_CONTRATO
# 13312021                       MONICA ALEJANDRA  TORRES PORES
# CO1PCCNTR2525614       INVERSER LTDA  INVERSIONES Y SERVICIOS
# GGC6762021           EMPRESA DE ENERGIA DE ARAUCA  ENELAR ESP
# CO1PCCNTR2090854          MUNICIPIO DE EL SANTUARIO ANTIOQUIA
# 2020AS390080                         MUNICIPIO DE SABANALARGA
#
#                      VALOR_TOTAL_CONTRATO          NOMBRE_GRUPO  \
# REFERENCIA_CONTRATO
# 13312021                         27000000             EJECUTIVO
# CO1PCCNTR2525614                  1424239  CORPORACION AUTONOMA
# GGC6762021                     8363818392             EJECUTIVO
# CO1PCCNTR2090854                433180320             EJECUTIVO
# 2020AS390080                    249161352             EJECUTIVO
#
#                                         NOMBRE_FAMILIA  \
# REFERENCIA_CONTRATO
# 13312021             INCLUSION SOCIAL Y RECONCILIACION
# CO1PCCNTR2525614                 NO APLICANO PERTENECE
# GGC6762021                             MINAS Y ENERGIA
# CO1PCCNTR2090854                      SERVICIO PUBLICO
# 2020AS390080                          SERVICIO PUBLICO
#
#                                           NOMBRE_CLASE  month  year  cluster  \
# REFERENCIA_CONTRATO
# 13312021             INCLUSION SOCIAL Y RECONCILIACION      6  2021      5.0
# CO1PCCNTR2525614                 NO APLICANO PERTENECE      5  2021      2.0
# GGC6762021                             MINAS Y ENERGIA      9  2021      5.0
# CO1PCCNTR2090854                      SERVICIO PUBLICO      5  2021      2.0
# 2020AS390080                          SERVICIO PUBLICO      3  2021      2.0
#
#                      indice_de_transparencia
# REFERENCIA_CONTRATO
# 13312021                            0.499161
# CO1PCCNTR2525614                    0.052300
# GGC6762021                          0.499161
# CO1PCCNTR2090854                    0.052300
# 2020AS390080                        0.052300

# %%
merged_data = contratos_indice.merge(anomalous_data, left_on='REFERENCIA_CONTRATO', right_on='original_index', how='left')
merged_data.head()
# Out:
#   MUNICIPIO DEPARTAMENTO ESTADO_DEL_PROCESO          FECHA_INICIO_CONTRATO  \
# 0    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 1    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 2    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 3    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 4    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
#
#               FECHA_FIN_CONTRATO         CLASE_PROCESO  \
# 0  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 1  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 2  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 3  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 4  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
#
#                  TIPO_PROCESO         TIPO_CONTRATO  \
# 0  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 1  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 2  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 3  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 4  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
#
#                                       NOMBRE_ENTIDAD  NIT_ENTIDAD  ...  \
# 0  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 1  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 2  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 3  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 4  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
#
#          RAZON_SOCIAL_CONTRATISTA VALOR_TOTAL_CONTRATO  NOMBRE_GRUPO  \
# 0  MONICA ALEJANDRA  TORRES PORES             27000000     EJECUTIVO
# 1  MONICA ALEJANDRA  TORRES PORES             27000000     EJECUTIVO
# 2  MONICA ALEJANDRA  TORRES PORES             27000000     EJECUTIVO
# 3  MONICA ALEJANDRA  TORRES PORES             27000000     EJECUTIVO
# 4  MONICA ALEJANDRA  TORRES PORES             27000000     EJECUTIVO
#
#                       NOMBRE_FAMILIA                       NOMBRE_CLASE month  \
# 0  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION     6
# 1  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION     6
# 2  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION     6
# 3  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION     6
# 4  INCLUSION SOCIAL Y RECONCILIACION  INCLUSION SOCIAL Y RECONCILIACION     6
#
#    year  cluster  indice_de_transparencia  anomaly_score
# 0  2021      5.0                 0.499161       0.827582
# 1  2021      5.0                 0.499161       0.741835
# 2  2021      5.0                 0.499161       0.524695
# 3  2021      5.0                 0.499161       0.534320
# 4  2021      5.0                 0.499161       0.852830
#
# [5 rows x 21 columns]

# %%
merged_data["indice_de_transparencia_del_contrato"] = merged_data["indice_de_transparencia"]*(1-merged_data["anomaly_score"])
merged_data.head()
# Out:
#   MUNICIPIO DEPARTAMENTO ESTADO_DEL_PROCESO          FECHA_INICIO_CONTRATO  \
# 0    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 1    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 2    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 3    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
# 4    BOGOTA       BOGOTA       EN EJECUCION  2021-06-01T00:00:00.000-05:00
#
#               FECHA_FIN_CONTRATO         CLASE_PROCESO  \
# 0  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 1  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 2  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 3  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
# 4  2021-11-30T00:00:00.000-05:00  CONTRATACION DIRECTA
#
#                  TIPO_PROCESO         TIPO_CONTRATO  \
# 0  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 1  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 2  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 3  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
# 4  ARRENDAMIENTO DE INMUEBLES  CONTRATACION DIRECTA
#
#                                       NOMBRE_ENTIDAD  NIT_ENTIDAD  ...  \
# 0  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 1  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 2  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 3  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
# 4  UARIVUNIDAD PARA LA ATENCION Y REPARACION INTE...    900490473  ...
#
#    VALOR_TOTAL_CONTRATO NOMBRE_GRUPO                     NOMBRE_FAMILIA  \
# 0              27000000    EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
# 1              27000000    EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
# 2              27000000    EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
# 3              27000000    EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
# 4              27000000    EJECUTIVO  INCLUSION SOCIAL Y RECONCILIACION
#
#                         NOMBRE_CLASE month  year  cluster  \
# 0  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
# 1  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
# 2  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
# 3  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
# 4  INCLUSION SOCIAL Y RECONCILIACION     6  2021      5.0
#
#    indice_de_transparencia  anomaly_score  \
# 0                 0.499161       0.827582
# 1                 0.499161       0.741835
# 2                 0.499161       0.524695
# 3                 0.499161       0.534320
# 4                 0.499161       0.852830
#
#    indice_de_transparencia_del_contrato
# 0                              0.086064
# 1                              0.128866
# 2                              0.237254
# 3                              0.232449
# 4                              0.073461
#
# [5 rows x 22 columns]

# %%
merged_data.to_csv("anomaly_data/contratos_indice_transparencia.csv")

# %%
merged_data.columns
# Out:
# Index(['MUNICIPIO', 'DEPARTAMENTO', 'ESTADO_DEL_PROCESO',
#        'FECHA_INICIO_CONTRATO', 'FECHA_FIN_CONTRATO', 'CLASE_PROCESO',
#        'TIPO_PROCESO', 'TIPO_CONTRATO', 'NOMBRE_ENTIDAD', 'NIT_ENTIDAD',
#        'ID_CONTRATISTA', 'RAZON_SOCIAL_CONTRATISTA', 'VALOR_TOTAL_CONTRATO',
#        'NOMBRE_GRUPO', 'NOMBRE_FAMILIA', 'NOMBRE_CLASE', 'month', 'year',
#        'cluster', 'indice_de_transparencia', 'anomaly_score',
#        'indice_de_transparencia_del_contrato'],
#       dtype='object')
